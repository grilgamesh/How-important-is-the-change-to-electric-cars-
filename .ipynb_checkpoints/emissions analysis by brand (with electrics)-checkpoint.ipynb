# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import random

# %%
euro = "data/Euro_6_latest.csv"
euro_df = pd.read_csv(euro, encoding='ANSI')
euro_df
# Out:
#      Manufacturer       Model                                 Description  \
# 0          ABARTH         595                             1.4 TJET 145bhp
# 1          ABARTH         595                             1.4 TJET 145bhp
# 2          ABARTH         595                            595 1.4 145 BHP
# 3          ABARTH         595                             595 1.4 145 BHP
# 4          ABARTH         595                 595 1.4 145 BHP Convertible
# ...           ...         ...                                         ...
# 6329        VOLVO  XC90, MY22  Recharge T8 Plug-in Hybrid Inscription Pro
# 6330        VOLVO  XC90, MY22         Recharge T8 Plug-in Hybrid R-Design
# 6331        VOLVO  XC90, MY22         Recharge T8 Plug-in Hybrid R-Design
# 6332        VOLVO  XC90, MY22     Recharge T8 Plug-in Hybrid R-Design Pro
# 6333        VOLVO  XC90, MY22     Recharge T8 Plug-in Hybrid R-Design Pro
#
#      Transmission Manual or Automatic  Engine Capacity             Fuel Type  \
# 0              M5              Manual           1368.0                Petrol
# 1              M5              Manual           1368.0                Petrol
# 2              M5              Manual           1368.0                Petrol
# 3              M5              Manual           1368.0                Petrol
# 4              M5              Manual           1368.0                Petrol
# ...           ...                 ...              ...                   ...
# 6329       8A-AWD           Automatic           1969.0  Electricity / Petrol
# 6330       8A-AWD           Automatic           1969.0  Electricity / Petrol
# 6331       8A-AWD           Automatic           1969.0  Electricity / Petrol
# 6332       8A-AWD           Automatic           1969.0  Electricity / Petrol
# 6333       8A-AWD           Automatic           1969.0  Electricity / Petrol
#
#                                   Powertrain  Engine Power (PS)  \
# 0           Internal Combustion Engine (ICE)              145.0
# 1           Internal Combustion Engine (ICE)              145.0
# 2           Internal Combustion Engine (ICE)              145.0
# 3           Internal Combustion Engine (ICE)              145.0
# 4           Internal Combustion Engine (ICE)              145.0
# ...                                      ...                ...
# 6329  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
# 6330  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
# 6331  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
# 6332  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
# 6333  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
#
#       Engine Power (Kw)  ...  Emissions CO [mg/km]  THC Emissions [mg/km]  \
# 0                 107.0  ...                 829.0                   39.0
# 1                 107.0  ...                 829.0                   39.0
# 2                 107.0  ...                 760.0                   52.0
# 3                 107.0  ...                 760.0                   52.0
# 4                 107.0  ...                 760.0                   52.0
# ...                 ...  ...                   ...                    ...
# 6329              288.0  ...                 706.0                    6.0
# 6330              288.0  ...                 706.0                    6.0
# 6331              288.0  ...                 706.0                    6.0
# 6332              288.0  ...                 706.0                    6.0
# 6333              288.0  ...                 706.0                    6.0
#
#       Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# 0                      20.0                          NaN
# 1                      20.0                          NaN
# 2                      27.0                          NaN
# 3                      27.0                          NaN
# 4                      27.0                          NaN
# ...                     ...                          ...
# 6329                    9.0                         14.0
# 6330                    9.0                         14.0
# 6331                    9.0                         14.0
# 6332                    9.0                         14.0
# 6333                    9.0                         14.0
#
#      Particulates [No.] [mg/km]  RDE NOx Urban RDE NOx Combined  \
# 0                           NaN            NaN              NaN
# 1                           NaN            NaN              NaN
# 2                           NaN            NaN              NaN
# 3                           NaN            NaN              NaN
# 4                           NaN            NaN              NaN
# ...                         ...            ...              ...
# 6329                       0.22            NaN              NaN
# 6330                       0.22            NaN              NaN
# 6331                       0.22            NaN              NaN
# 6332                       0.22            NaN              NaN
# 6333                       0.22            NaN              NaN
#
#       Noise Level dB(A)    Date of change  Unnamed: 44
# 0                  74.0  09 February 2022          NaN
# 1                  74.0  09 February 2022          NaN
# 2                  73.5   05 October 2020          NaN
# 3                  73.5   05 October 2020          NaN
# 4                  73.5      02 July 2021          NaN
# ...                 ...               ...          ...
# 6329               67.0    13 August 2021          NaN
# 6330               67.0    13 August 2021          NaN
# 6331               67.0    13 August 2021          NaN
# 6332               67.0    13 August 2021          NaN
# 6333               67.0    13 August 2021          NaN
#
# [6334 rows x 45 columns]

# %%
euro_emissions = euro_df.drop(euro_df.loc[euro_df["Fuel Type"]  == "Electricity"].index)

euro_emissions = euro_emissions.groupby(['Manufacturer', 'Model', 'Description'], as_index=False).mean()
euro_emissions
# Out:
#      Manufacturer       Model  \
# 0          ABARTH         595
# 1          ABARTH         595
# 2          ABARTH         595
# 3          ABARTH         595
# 4          ABARTH         595
# ...           ...         ...
# 3598        VOLVO  XC90, MY22
# 3599        VOLVO  XC90, MY22
# 3600        VOLVO  XC90, MY22
# 3601        VOLVO  XC90, MY22
# 3602        VOLVO  XC90, MY22
#
#                                             Description  Engine Capacity  \
# 0                                       1.4 TJET 145bhp           1368.0
# 1                                       595 1.4 145 BHP           1368.0
# 2                                      595 1.4 145 BHP            1368.0
# 3                           595 1.4 145 BHP Convertible           1368.0
# 4                                  595 1.4 TJET 145 BHP           1368.0
# ...                                                 ...              ...
# 3598             Recharge T8 Plug-in Hybrid Inscription           1969.0
# 3599  Recharge T8 Plug-in Hybrid Inscription Expression           1969.0
# 3600         Recharge T8 Plug-in Hybrid Inscription Pro           1969.0
# 3601                Recharge T8 Plug-in Hybrid R-Design           1969.0
# 3602            Recharge T8 Plug-in Hybrid R-Design Pro           1969.0
#
#       Engine Power (PS)  Engine Power (Kw)  \
# 0                 145.0              107.0
# 1                 145.0              107.0
# 2                 145.0              107.0
# 3                 145.0              107.0
# 4                 145.0              107.0
# ...                 ...                ...
# 3598              390.0              288.0
# 3599              390.0              288.0
# 3600              390.0              288.0
# 3601              390.0              288.0
# 3602              390.0              288.0
#
#       Electric energy consumption Miles/kWh  wh/km  Maximum range (Km)  \
# 0                                       0.0    NaN                 NaN
# 1                                       0.0    NaN                 NaN
# 2                                       0.0    NaN                 NaN
# 3                                       0.0    NaN                 NaN
# 4                                       0.0    NaN                 NaN
# ...                                     ...    ...                 ...
# 3598                                    2.4  254.0                50.0
# 3599                                    2.4  254.0                50.0
# 3600                                    2.4  254.0                50.0
# 3601                                    2.4  254.0                50.0
# 3602                                    2.5  241.0                46.0
#
#       Maximum range (Miles)  ...  Electric Range City Km  \
# 0                       NaN  ...                     NaN
# 1                       NaN  ...                     NaN
# 2                       NaN  ...                     NaN
# 3                       NaN  ...                     NaN
# 4                       NaN  ...                     NaN
# ...                     ...  ...                     ...
# 3598                   31.0  ...                    51.0
# 3599                   31.0  ...                    51.0
# 3600                   31.0  ...                    51.0
# 3601                   31.0  ...                    51.0
# 3602                   29.0  ...                    51.0
#
#       Emissions CO [mg/km]  THC Emissions [mg/km]  Emissions NOx [mg/km]  \
# 0                    829.0                   39.0                   20.0
# 1                    760.0                   52.0                   27.0
# 2                    760.0                   52.0                   27.0
# 3                    760.0                   52.0                   27.0
# 4                    760.0                   52.0                   27.0
# ...                    ...                    ...                    ...
# 3598                 706.0                    6.0                    9.0
# 3599                 706.0                    6.0                    9.0
# 3600                 706.0                    6.0                    9.0
# 3601                 706.0                    6.0                    9.0
# 3602                 706.0                    6.0                    9.0
#
#       THC + NOx Emissions [mg/km]  Particulates [No.] [mg/km]  RDE NOx Urban  \
# 0                             NaN                         NaN            NaN
# 1                             NaN                         NaN            NaN
# 2                             NaN                         NaN            NaN
# 3                             NaN                         NaN            NaN
# 4                             NaN                         NaN            NaN
# ...                           ...                         ...            ...
# 3598                         14.0                        0.22            NaN
# 3599                         14.0                        0.22            NaN
# 3600                         14.0                        0.22            NaN
# 3601                         14.0                        0.22            NaN
# 3602                         14.0                        0.22            NaN
#
#       RDE NOx Combined  Noise Level dB(A)  Unnamed: 44
# 0                  NaN               74.0          NaN
# 1                  NaN               73.5          NaN
# 2                  NaN               73.5          NaN
# 3                  NaN               73.5          NaN
# 4                  NaN               73.5          NaN
# ...                ...                ...          ...
# 3598               NaN               67.0          NaN
# 3599               NaN               67.0          NaN
# 3600               NaN               67.0          NaN
# 3601               NaN               67.0          NaN
# 3602               NaN               67.0          NaN
#
# [3603 rows x 38 columns]

# %%
manu_emissions = euro_emissions.groupby(['Manufacturer'], as_index=False).mean().sort_values(by='WLTP CO2')
manu_emissions = manu_emissions[['Manufacturer', 'WLTP CO2']]
manu_emissions
# Out:
#             Manufacturer    WLTP CO2
# 36                SUZUKI  121.500000
# 37                TOYOTA  132.070381
# 16               HYUNDAI  134.907609
# 15                 HONDA  136.570792
# 18                   KIA  137.378819
# 38                 VOLVO  140.786111
# 31               RENAULT  140.910870
# 9                  DACIA  141.895115
# 12                  FIAT  143.787234
# 33                  SEAT  143.881081
# 29                NISSAN  143.886364
# 8                CITROEN  146.281250
# 30               PEUGEOT  146.306818
# 10                    DS  147.900000
# 23                 MAZDA  148.549383
# 20                 LEXUS  149.959016
# 2                 ALPINE  157.071429
# 25          MG MOTORS UK  157.681818
# 0                 ABARTH  166.022222
# 13                  FORD  170.046748
# 27  MORGAN MOTOR COMPANY  171.000000
# 26            MITSUBISHI  175.428571
# 24         MERCEDES-BENZ  177.129167
# 7          CHRYSLER JEEP  178.088235
# 34             SSANGYONG  178.259259
# 1             ALFA ROMEO  183.122222
# 5               CADILLAC  186.666667
# 35                SUBARU  188.600000
# 17                JAGUAR  203.575472
# 14               GENESIS  203.707317
# 21                 LOTUS  211.687500
# 19            LAND ROVER  228.951567
# 22              MASERATI  268.838710
# 28               McLaren  276.000000
# 6              CHEVROLET  277.000000
# 3   ASTON MARTIN LAGONDA  282.476190
# 4         BENTLEY MOTORS  289.705882
# 11               FERRARI  312.642857
# 32           Rolls Royce  361.900000

# %%
emissions_superstars_pooperstars = []
print((len(manu_emissions)-3, len(manu_emissions)))
for n in range (0, 3):
    emissions_superstars_pooperstars.append(manu_emissions.iloc[n]['Manufacturer'])
    
for n in range (len(manu_emissions)-3, len(manu_emissions)):
    emissions_superstars_pooperstars.append(manu_emissions.iloc[n]['Manufacturer'])
    
print(emissions_superstars_pooperstars)
# Out:
# (36, 39)
# ['SUZUKI', 'TOYOTA', 'HYUNDAI', 'BENTLEY MOTORS', 'FERRARI', 'Rolls Royce']

# %%
cars = []
euro_emissions_crop = euro_emissions[['Manufacturer', 'Model', 'Description', 'WLTP CO2']]

for manufacturer in emissions_superstars_pooperstars:
    carDF = euro_emissions_crop.loc[((euro_emissions_crop["Manufacturer"] == manufacturer ))]
    carDF.sort_values(by="WLTP CO2", ascending=True)
    cars.append(carDF) 

cars
# Out:
# [     Manufacturer        Model                           Description  WLTP CO2
#  3142       SUZUKI       Across       ACROSS 2.5 PHEV SZ5 ALLGRIP CVT     149.0
#  3143       SUZUKI        Ignis                 IGNIS 1.2 HYBRID SZ-T     112.0
#  3144       SUZUKI        Ignis             IGNIS 1.2 HYBRID SZ-T CVT     122.0
#  3145       SUZUKI        Ignis                  IGNIS 1.2 HYBRID SZ3     110.0
#  3146       SUZUKI        Ignis                  IGNIS 1.2 HYBRID SZ5     112.0
#  3147       SUZUKI        Ignis              IGNIS 1.2 HYBRID SZ5 4x4     121.0
#  3148       SUZUKI        Ignis              IGNIS 1.2 HYBRID SZ5 CVT     122.0
#  3149       SUZUKI      S-cross               S-CROSS 1.4 HYBRID SZ-T     122.0
#  3150       SUZUKI      S-cross          S-CROSS 1.4 HYBRID SZ-T Auto     129.0
#  3151       SUZUKI      S-cross                S-CROSS 1.4 HYBRID SZ4     122.0
#  3152       SUZUKI      S-cross                S-CROSS 1.4 HYBRID SZ5     122.0
#  3153       SUZUKI      S-cross        S-CROSS 1.4 HYBRID SZ5 ALLGRIP     133.0
#  3154       SUZUKI      S-cross   S-CROSS 1.4 HYBRID SZ5 ALLGRIP Auto     142.0
#  3155       SUZUKI        Swace             SWACE 1.8 HYBRID SZ-T CVT     103.0
#  3156       SUZUKI        Swace              SWACE 1.8 HYBRID SZ5 CVT     103.0
#  3157       SUZUKI        Swift         SWIFT 1.2 DualJet HYBRID SZ-L     106.0
#  3158       SUZUKI        Swift         SWIFT 1.2 DualJet HYBRID SZ-T     106.0
#  3159       SUZUKI        Swift     SWIFT 1.2 DualJet HYBRID SZ-T CVT     115.0
#  3160       SUZUKI        Swift          SWIFT 1.2 DualJet HYBRID SZ5     106.0
#  3161       SUZUKI        Swift  SWIFT 1.2 DualJet HYBRID SZ5 ALLGRIP     121.0
#  3162       SUZUKI        Swift      SWIFT 1.2 DualJet HYBRID SZ5 CVT     115.0
#  3163       SUZUKI  Swift Sport          SWIFT 1.4 B/JET HYBRID SPORT     125.0
#  3164       SUZUKI       Vitara                VITARA 1.4 HYBRID SZ-T     121.0
#  3165       SUZUKI       Vitara        VITARA 1.4 HYBRID SZ-T ALLGRIP     132.0
#  3166       SUZUKI       Vitara           VITARA 1.4 HYBRID SZ-T Auto     129.0
#  3167       SUZUKI       Vitara                 VITARA 1.4 HYBRID SZ4     121.0
#  3168       SUZUKI       Vitara                 VITARA 1.4 HYBRID SZ5     121.0
#  3169       SUZUKI       Vitara         VITARA 1.4 HYBRID SZ5 ALLGRIP     132.0
#  3170       SUZUKI       Vitara    VITARA 1.4 HYBRID SZ5 ALLGRIP Auto     142.0
#  3171       SUZUKI       Vitara            VITARA 1.4 HYBRID SZ5 Auto     129.0,
#       Manufacturer         Model                          Description  WLTP CO2
#  3172       TOYOTA          Aygo             X-TREND TSS 1.0 Auto 5dr     113.0
#  3173       TOYOTA          Aygo           X-TREND TSS 1.0 Manual 5dr     113.0
#  3174       TOYOTA          Aygo            XCLUSIVE TSS 1.0 Auto 5dr     114.0
#  3175       TOYOTA          Aygo          XCLUSIVE TSS 1.0 Manual 5dr     114.0
#  3176       TOYOTA          Aygo               XPLAY TSS 1.0 Auto 5dr     118.0
#  ...           ...           ...                                  ...       ...
#  3508       TOYOTA  Yaris Hybrid       Excel Hybrid (Pannoramic Roof)      98.0
#  3509       TOYOTA  Yaris Hybrid  Excel Hybrid (Tech Pack & Pan Roof)      98.0
#  3510       TOYOTA  Yaris Hybrid             Excel Hybrid (Tech Pack)      98.0
#  3511       TOYOTA  Yaris Hybrid                          Icon Hybrid      92.0
#  3512       TOYOTA  Yaris Hybrid                Launch Edition Hybrid      98.0
#
#  [341 rows x 4 columns],
#      Manufacturer           Model  \
#  685      HYUNDAI           Bayon
#  686      HYUNDAI           Bayon
#  687      HYUNDAI           Bayon
#  688      HYUNDAI           IONIQ
#  689      HYUNDAI           IONIQ
#  690      HYUNDAI            Kona
#  691      HYUNDAI            Kona
#  692      HYUNDAI            Kona
#  693      HYUNDAI            Kona
#  694      HYUNDAI            Kona
#  695      HYUNDAI            Kona
#  696      HYUNDAI            Kona
#  697      HYUNDAI        Santa Fe
#  698      HYUNDAI        Santa Fe
#  699      HYUNDAI        Santa Fe
#  700      HYUNDAI        Santa Fe
#  701      HYUNDAI        Santa Fe
#  702      HYUNDAI          Tucson
#  703      HYUNDAI          Tucson
#  704      HYUNDAI          Tucson
#  705      HYUNDAI          Tucson
#  706      HYUNDAI          Tucson
#  707      HYUNDAI          Tucson
#  708      HYUNDAI            i10
#  709      HYUNDAI            i10
#  710      HYUNDAI            i10
#  711      HYUNDAI            i10
#  712      HYUNDAI            i10
#  713      HYUNDAI            i10
#  714      HYUNDAI             i20
#  715      HYUNDAI             i20
#  716      HYUNDAI             i20
#  717      HYUNDAI             i20
#  718      HYUNDAI             i20
#  719      HYUNDAI    i30 Fastback
#  720      HYUNDAI  i30 Fastback N
#  721      HYUNDAI   i30 Hatchback
#  722      HYUNDAI   i30 Hatchback
#  723      HYUNDAI   i30 Hatchback
#  724      HYUNDAI   i30 Hatchback
#  725      HYUNDAI   i30 Hatchback
#  726      HYUNDAI           i30 N
#  727      HYUNDAI      i30 Tourer
#  728      HYUNDAI      i30 Tourer
#  729      HYUNDAI      i30 Tourer
#  730      HYUNDAI      i30 Tourer
#
#                                          Description  WLTP CO2
#  685                                         Premium    120.50
#  686                                      SE Connect    119.50
#  687                                        Ultimate    121.00
#  688                                      Premium SE    105.00
#  689                            SE Connect & Premium    102.00
#  690                     1.0 T-GDi 48V MHEV, Premium    137.00
#  691                  1.0 T-GDi 48V MHEV, SE Connect    135.00
#  692           1.0 T-GDi 48V MHEV, Ultimate & N Line    138.00
#  693                    Hybrid Premium 21MY Facelift    114.00
#  694                   Hybrid Ultimate 21MY Facelift    115.00
#  695                                          Kona N    194.00
#  696                                      SE Connect    112.00
#  697                              Premium & Ultimate    172.00
#  698                              Premium Hybrid 2WD    145.00
#  699                              Premium Hybrid 4WD    159.00
#  700                             Ultimate Hybrid 2WD    152.00
#  701                             Ultimate Hybrid 4WD    168.00
#  702                                          N Line    145.00
#  703                                        N Line S    149.75
#  704                                         Premium    145.25
#  705                              Premium & Ultimate    165.00
#  706                                      SE Connect    139.00
#  707                                        Ultimate    154.75
#  708                                    1.0l Premium    123.00
#  709                                         1.0l SE    114.00
#  710                                 1.0l SE Connect    122.50
#  711                                    1.2l Premium    127.00
#  712                                 1.2l SE Connect    127.00
#  713                                    N Line T-GDi    123.00
#  714  1.0l T-GDi 48v Mild Hybrid, Premium & Ultimate    119.50
#  715          1.0l T-GDi 48v Mild Hybrid, SE Connect    116.00
#  716                                         Element    120.00
#  717                                               N    158.00
#  718                                          N Line    120.00
#  719                      1.5l T-GDi 48v Mild Hybrid    138.50
#  720                          Fastback N Performance    186.50
#  721             1.0l T-GDi 48v Mild Hybrid, Premium    121.50
#  722          1.0l T-GDi 48v Mild Hybrid, SE Connect    120.50
#  723              1.5l T-GDi 48v Mild Hybrid, N Line    140.00
#  724              1.6l CRDi 48v Mild Hybrid, Premium    124.50
#  725           1.6l CRDi 48v Mild Hybrid, SE Connect    123.50
#  726                                   N Performance    186.50
#  727             1.0l T-GDi 48v Mild Hybrid, Premium    121.00
#  728          1.0l T-GDi 48v Mild Hybrid, SE Connect    119.00
#  729              1.6l CRDi 48v Mild Hybrid, Premium    124.00
#  730           1.6l CRDi 48v Mild Hybrid, SE Connect    122.50  ,
#         Manufacturer                   Model  \
#  110  BENTLEY MOTORS           Bentayga MY21
#  111  BENTLEY MOTORS           Bentayga MY21
#  112  BENTLEY MOTORS     Continental GT MY21
#  113  BENTLEY MOTORS     Continental GT MY21
#  114  BENTLEY MOTORS     Continental GT MY22
#  115  BENTLEY MOTORS     Continental GT MY22
#  116  BENTLEY MOTORS  Continental GT V8 MY21
#  117  BENTLEY MOTORS  Continental GT V8 MY21
#  118  BENTLEY MOTORS  Continental GT V8 MY21
#  119  BENTLEY MOTORS  Continental GT V8 MY21
#  120  BENTLEY MOTORS  Continental GT V8 MY22
#  121  BENTLEY MOTORS  Continental GT V8 MY22
#  122  BENTLEY MOTORS        Flying Spur MY21
#  123  BENTLEY MOTORS        Flying Spur MY21
#  124  BENTLEY MOTORS        Flying Spur MY21
#  125  BENTLEY MOTORS        Flying Spur MY22
#  126  BENTLEY MOTORS        Flying Spur MY22
#
#                                      Description  WLTP CO2
#  110                             Bentayga Hybrid      82.0
#  111                                 Bentayga V8     298.0
#  112                              Continental GT     308.0
#  113                  Continental GT Convertible     336.0
#  114                        Continental GT Speed     311.0
#  115            Continental GT Speed Convertible     320.0
#  116       Continental GT V8 Convertible Euro 6d     284.0
#  117  Continental GT V8 Convertible Euro 6d-TEMP     281.0
#  118                   Continental GT V8 Euro 6d     275.0
#  119              Continental GT V8 Euro 6d-TEMP     278.0
#  120                           Continental GT V8     275.0
#  121               Continental GT V8 Convertible     284.0
#  122                                          V8     288.0
#  123                                 W12 Euro 6d     340.0
#  124                            W12 Euro 6d-TEMP     337.0
#  125                                 Flying Spur     340.0
#  126                              Flying Spur V8     288.0  ,
#      Manufacturer      Model      Description  WLTP CO2
#  412      FERRARI        488            Pista     282.0
#  413      FERRARI        488     Pista Spider     289.0
#  414      FERRARI        812              GTS     373.0
#  415      FERRARI        812        Superfast     366.0
#  416      FERRARI         F8           Spider     296.0
#  417      FERRARI         F8          Tributo     292.0
#  418      FERRARI       GTC4            Lusso     366.0
#  419      FERRARI       GTC4          Lusso T     294.0
#  420      FERRARI      Monza              SP1     366.0
#  421      FERRARI      Monza              SP2     366.0
#  422      FERRARI  Portofino        Portofino     267.0
#  423      FERRARI       Roma             Roma     255.0
#  424      FERRARI       SF90  Assetto Fiorano     285.0
#  425      FERRARI       SF90         Stradale     280.0,
#       Manufacturer     Model                 Description  WLTP CO2
#  2905  Rolls Royce  Cullinan                    Cullinan     372.5
#  2906  Rolls Royce  Cullinan        Cullinan Black Badge     376.5
#  2907  Rolls Royce      Dawn                        Dawn     369.0
#  2908  Rolls Royce      Dawn    Dawn Black Badge Edition     364.0
#  2909  Rolls Royce     Ghost                       Ghost     353.0
#  2910  Rolls Royce     Ghost    Ghost Extended Wheelbase     353.0
#  2911  Rolls Royce   Phantom                     Phantom     353.5
#  2912  Rolls Royce   Phantom  Phantom Extended Wheelbase     353.5
#  2913  Rolls Royce    Wraith                      Wraith     360.0
#  2914  Rolls Royce    Wraith  Wraith Black Badge Edition     364.0]

# %%
# Put treatments into a list for for loop (and later for plot labels)
#treatments = [capomulin, ramicane, infubinol, ceftamin]


# Create empty list to fill with emissions data (for plotting)
outliers = []
quartile_sum = pd.DataFrame({})
# Calculate the IQR and quantitatively determine if there are any potential outliers. 


for brand in cars:
    #instantiate q0->5
    quartiles = brand["WLTP CO2"].quantile([.25,.5,.75])
    
    lowerq = quartiles[0.25]
    median = quartiles[0.5]    
    upperq = quartiles[0.75]
    lowest = brand["WLTP CO2"].min()
    highest = brand["WLTP CO2"].max()
    
    iqr = upperq-lowerq
    
    #outlier check
    #HANG ON surely this can be done simpler with booleans
    x = brand.loc[brand["WLTP CO2"] < (lowerq - iqr*1.5)]
    if len(x) > 0:
        outliers.append(x["Description"])
        
    x = brand.loc[brand["WLTP CO2"] > (upperq + iqr*1.5)]
    if len(x) >0:
        outliers.append(x["Description"])
        
#investigate a better way to do this...
    cardict = {"brand": brand["Manufacturer"], 
                "Q0": round(lowest, 1), 
                "Q1": round(lowerq, 1), 
                "Q2": round(median, 1), 
                "Q3": round(upperq, 1), 
                "Q4": round(highest, 1)}   
    quartile_sum = quartile_sum.append(cardict, ignore_index=True)
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # Determine outliers using upper and lower bounds
print(f"there are {len(outliers)} outliers in the data: {outliers}")
    # add subset 
    
# # format nicely    
quartile_sum = quartile_sum.transpose()
# quartile_sum.columns = quartile_sum.iloc[0] 
# quartile_sum = quartile_sum[1:]
quartile_sum
# Out:
# there are 4 outliers in the data: [3337         F SPORT Takumi Pack [Sunroof]
# 3338              F SPORTPremium Plus Pack
# 3339    F SPORTPremium Plus Pack [Sunroof]
# 3352        1.8L PHV Business Edition Plus
# 3353                        1.8L PHV Excel
# 3447                     2.5L PHEV Dynamic
# 3448             2.5L PHEV Dynamic Premium
# 3449        RAV4 Design 2.5 Plug-in Hybrid
# Name: Description, dtype: object, 3303                                    1.6 Turbo
# 3304                       1.6 Turbo Circuit Pack
# 3305                   1.6 Turbo Convenience Pack
# 3306                       2.0L Auto Blue Edition
# 3307    2.0L Auto Blue Edition + Performance Pack
#                           ...
# 3384         Shuttle Medium 2.0 Manual 150 + Navi
# 3385                   VIP Long 2.0 Automatic 180
# 3450                                         3.0L
# 3451                                     3.0L Pro
# 3452                                          2.0
# Name: Description, Length: 65, dtype: object, 695                    Kona N
# 720    Fastback N Performance
# 726             N Performance
# Name: Description, dtype: object, 110    Bentayga Hybrid
# Name: Description, dtype: object]
#                                                        0  \
# brand  3142    SUZUKI
# 3143    SUZUKI
# 3144    SUZUKI
# 3...
# Q0                                                 103.0
# Q1                                                 112.8
# Q2                                                 121.5
# Q3                                                 129.0
# Q4                                                 149.0
#
#                                                        1  \
# brand  3172    TOYOTA
# 3173    TOYOTA
# 3174    TOYOTA
# 3...
# Q0                                                   0.0
# Q1                                                 112.0
# Q2                                                 119.0
# Q3                                                 132.0
# Q4                                                 258.0
#
#                                                        2  \
# brand  685    HYUNDAI
# 686    HYUNDAI
# 687    HYUNDAI
# 6...
# Q0                                                 102.0
# Q1                                                 120.1
# Q2                                                 124.2
# Q3                                                 145.2
# Q4                                                 194.0
#
#                                                        3  \
# brand  110    BENTLEY MOTORS
# 111    BENTLEY MOTORS
# 11...
# Q0                                                  82.0
# Q1                                                 281.0
# Q2                                                 288.0
# Q3                                                 320.0
# Q4                                                 340.0
#
#                                                        4  \
# brand  412    FERRARI
# 413    FERRARI
# 414    FERRARI
# 4...
# Q0                                                 255.0
# Q1                                                 282.8
# Q2                                                 293.0
# Q3                                                 366.0
# Q4                                                 373.0
#
#                                                        5
# brand  2905    Rolls Royce
# 2906    Rolls Royce
# 2907  ...
# Q0                                                 353.0
# Q1                                                 353.5
# Q2                                                 362.0
# Q3                                                 367.8
# Q4                                                 376.5

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
for car in cars:
    car=car.dropna()

data = cars[0]["WLTP CO2"], \
        cars[1]["WLTP CO2"], \
        cars[2]["WLTP CO2"], \
        cars[3]["WLTP CO2"], \
        cars[4]["WLTP CO2"], \
        cars[5]["WLTP CO2"]

fig, ax = plt.subplots()
ax.set_title('Comparing the emissions vehicles by the three cleanest and three most polluting car companies')
ax.boxplot(data, labels = emissions_superstars_pooperstars, sym="*", widths=(0.8))

plt.xlabel("Manufacturer")
plt.ylabel("WLTP CO2")


fig.set_figheight(8)
fig.set_figwidth(13)
plt.show()
