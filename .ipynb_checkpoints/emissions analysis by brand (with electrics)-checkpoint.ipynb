# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import random

# %%
euro = "data/Euro_6_CLEAN.csv"
euro_df = pd.read_csv(euro, encoding='ANSI')
euro_df
# Out:
#       Unnamed: 0 Manufacturer       Model  \
# 0              0       ABARTH         595
# 1              1       ABARTH         595
# 2              2       ABARTH         595
# 3              3       ABARTH         595
# 4              4       ABARTH         595
# ...          ...          ...         ...
# 6329        6329        VOLVO  XC90, MY22
# 6330        6330        VOLVO  XC90, MY22
# 6331        6331        VOLVO  XC90, MY22
# 6332        6332        VOLVO  XC90, MY22
# 6333        6333        VOLVO  XC90, MY22
#
#                                      Description Transmission  \
# 0                                1.4 TJET 145bhp           M5
# 1                                1.4 TJET 145bhp           M5
# 2                               595 1.4 145 BHP            M5
# 3                                595 1.4 145 BHP           M5
# 4                    595 1.4 145 BHP Convertible           M5
# ...                                          ...          ...
# 6329  Recharge T8 Plug-in Hybrid Inscription Pro       8A-AWD
# 6330         Recharge T8 Plug-in Hybrid R-Design       8A-AWD
# 6331         Recharge T8 Plug-in Hybrid R-Design       8A-AWD
# 6332     Recharge T8 Plug-in Hybrid R-Design Pro       8A-AWD
# 6333     Recharge T8 Plug-in Hybrid R-Design Pro       8A-AWD
#
#      Manual or Automatic  Engine Capacity             Fuel Type  \
# 0                 Manual           1368.0                Petrol
# 1                 Manual           1368.0                Petrol
# 2                 Manual           1368.0                Petrol
# 3                 Manual           1368.0                Petrol
# 4                 Manual           1368.0                Petrol
# ...                  ...              ...                   ...
# 6329           Automatic           1969.0  Electricity / Petrol
# 6330           Automatic           1969.0  Electricity / Petrol
# 6331           Automatic           1969.0  Electricity / Petrol
# 6332           Automatic           1969.0  Electricity / Petrol
# 6333           Automatic           1969.0  Electricity / Petrol
#
#                                   Powertrain  Engine Power (PS)  ...  \
# 0           Internal Combustion Engine (ICE)              145.0  ...
# 1           Internal Combustion Engine (ICE)              145.0  ...
# 2           Internal Combustion Engine (ICE)              145.0  ...
# 3           Internal Combustion Engine (ICE)              145.0  ...
# 4           Internal Combustion Engine (ICE)              145.0  ...
# ...                                      ...                ...  ...
# 6329  Plug-in Hybrid Electric Vehicle (PHEV)              390.0  ...
# 6330  Plug-in Hybrid Electric Vehicle (PHEV)              390.0  ...
# 6331  Plug-in Hybrid Electric Vehicle (PHEV)              390.0  ...
# 6332  Plug-in Hybrid Electric Vehicle (PHEV)              390.0  ...
# 6333  Plug-in Hybrid Electric Vehicle (PHEV)              390.0  ...
#
#       Emissions CO [mg/km]  THC Emissions [mg/km]  Emissions NOx [mg/km]  \
# 0                    829.0                   39.0                   20.0
# 1                    829.0                   39.0                   20.0
# 2                    760.0                   52.0                   27.0
# 3                    760.0                   52.0                   27.0
# 4                    760.0                   52.0                   27.0
# ...                    ...                    ...                    ...
# 6329                 706.0                    6.0                    9.0
# 6330                 706.0                    6.0                    9.0
# 6331                 706.0                    6.0                    9.0
# 6332                 706.0                    6.0                    9.0
# 6333                 706.0                    6.0                    9.0
#
#       THC + NOx Emissions [mg/km]  Particulates [No.] [mg/km] RDE NOx Urban  \
# 0                            59.0                         NaN           NaN
# 1                            59.0                         NaN           NaN
# 2                            79.0                         NaN           NaN
# 3                            79.0                         NaN           NaN
# 4                            79.0                         NaN           NaN
# ...                           ...                         ...           ...
# 6329                         14.0                        0.22           NaN
# 6330                         14.0                        0.22           NaN
# 6331                         14.0                        0.22           NaN
# 6332                         14.0                        0.22           NaN
# 6333                         14.0                        0.22           NaN
#
#       RDE NOx Combined Noise Level dB(A)  Date of change  Cleaned CO2
# 0                  NaN              74.0       09-Feb-22        161.0
# 1                  NaN              74.0       09-Feb-22        153.0
# 2                  NaN              73.5       05-Oct-20        169.0
# 3                  NaN              73.5       05-Oct-20        162.0
# 4                  NaN              73.5       02-Jul-21        169.0
# ...                ...               ...             ...          ...
# 6329               NaN              67.0       13-Aug-21         76.0
# 6330               NaN              67.0       13-Aug-21         57.0
# 6331               NaN              67.0       13-Aug-21         76.0
# 6332               NaN              67.0       13-Aug-21         57.0
# 6333               NaN              67.0       13-Aug-21         76.0
#
# [6334 rows x 46 columns]

# %%
euro_emissions = euro_df.groupby(['Manufacturer', 'Model', 'Description'], as_index=False).mean()

# %%
manu_emissions = euro_emissions.groupby(['Manufacturer'], as_index=False).mean().sort_values(by='Cleaned CO2')
manu_emissions = manu_emissions[['Manufacturer', 'Cleaned CO2']]
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.bar(manu_emissions["Manufacturer"],manu_emissions["Cleaned CO2"])
ax.set_ylabel('CO2 Emissions')
ax.set_title('Average CO2 of cars by manufacturers')

plt.xticks(manu_emissions["Manufacturer"], rotation='vertical')
fig.set_figheight(8)
fig.set_figwidth(13)
plt.show()

# %%
emissions_superstars_pooperstars = []
for n in range (0, 3):
    emissions_superstars_pooperstars.append(manu_emissions.iloc[n]['Manufacturer'])
    
for n in range (len(manu_emissions)-3, len(manu_emissions)):
    emissions_superstars_pooperstars.append(manu_emissions.iloc[n]['Manufacturer'])
    
print(emissions_superstars_pooperstars)
# Out:
# ['0', 'TESLA', 'SMART', 'BENTLEY MOTORS', 'FERRARI', 'Rolls Royce']

# %%
cars = []
euro_emissions_crop = euro_emissions[['Manufacturer', 'Model', 'Description', 'Cleaned CO2']]

for manufacturer in emissions_superstars_pooperstars:
    carDF = euro_emissions_crop.loc[((euro_emissions_crop["Manufacturer"] == manufacturer ))]
    carDF.sort_values(by="Cleaned CO2", ascending=True)
    cars.append(carDF) 

cars
# Out:
# [  Manufacturer Model Description  Cleaned CO2
#  0            0     0           0          0.0,
#       Manufacturer    Model                     Description  Cleaned CO2
#  3269        TESLA  Model 3           Long Range (E3CD#Gb1)          0.0
#  3270        TESLA  Model 3           Long Range (E3LD#Gb1)          0.0
#  3271        TESLA  Model 3            Long Range (E5D##b1)          0.0
#  3272        TESLA  Model 3           Performance (E3LD##p)          0.0
#  3273        TESLA  Model 3            Performance (E5D#Gp)          0.0
#  3274        TESLA  Model 3  Standard Range Plus (E1CR#Gb1)          0.0
#  3275        TESLA  Model 3  Standard Range Plus (E1LR#Gb1)          0.0
#  3276        TESLA  Model 3   Standard Range Plus (E6R#Gb1)          0.0
#  3277        TESLA  Model S              Long Range (SA3EB)          0.0
#  3278        TESLA  Model S             Performance (SA3EP)          0.0
#  3279        TESLA  Model X              Long Range (XA3EB)          0.0
#  3280        TESLA  Model X             Performance (XA3EP)          0.0,
#       Manufacturer                            Model Description  Cleaned CO2
#  3200        SMART                          forfour          EQ          0.0
#  3201        SMART        forfour Model Year 2021.5          EQ          0.0
#  3202        SMART                    fortwo cabrio          EQ          0.0
#  3203        SMART  fortwo cabrio Model Year 2021.5          EQ          0.0
#  3204        SMART                     fortwo coupe          EQ          0.0
#  3205        SMART   fortwo coupe Model Year 2021.5          EQ          0.0,
#         Manufacturer                   Model  \
#  111  BENTLEY MOTORS           Bentayga MY21
#  112  BENTLEY MOTORS           Bentayga MY21
#  113  BENTLEY MOTORS     Continental GT MY21
#  114  BENTLEY MOTORS     Continental GT MY21
#  115  BENTLEY MOTORS     Continental GT MY22
#  116  BENTLEY MOTORS     Continental GT MY22
#  117  BENTLEY MOTORS  Continental GT V8 MY21
#  118  BENTLEY MOTORS  Continental GT V8 MY21
#  119  BENTLEY MOTORS  Continental GT V8 MY21
#  120  BENTLEY MOTORS  Continental GT V8 MY21
#  121  BENTLEY MOTORS  Continental GT V8 MY22
#  122  BENTLEY MOTORS  Continental GT V8 MY22
#  123  BENTLEY MOTORS        Flying Spur MY21
#  124  BENTLEY MOTORS        Flying Spur MY21
#  125  BENTLEY MOTORS        Flying Spur MY21
#  126  BENTLEY MOTORS        Flying Spur MY22
#  127  BENTLEY MOTORS        Flying Spur MY22
#
#                                      Description  Cleaned CO2
#  111                             Bentayga Hybrid         82.0
#  112                                 Bentayga V8        298.0
#  113                              Continental GT        308.0
#  114                  Continental GT Convertible        336.0
#  115                        Continental GT Speed        311.0
#  116            Continental GT Speed Convertible        320.0
#  117       Continental GT V8 Convertible Euro 6d        284.0
#  118  Continental GT V8 Convertible Euro 6d-TEMP        281.0
#  119                   Continental GT V8 Euro 6d        275.0
#  120              Continental GT V8 Euro 6d-TEMP        278.0
#  121                           Continental GT V8        275.0
#  122               Continental GT V8 Convertible        284.0
#  123                                          V8        288.0
#  124                                 W12 Euro 6d        340.0
#  125                            W12 Euro 6d-TEMP        337.0
#  126                                 Flying Spur        340.0
#  127                              Flying Spur V8        288.0  ,
#      Manufacturer      Model      Description  Cleaned CO2
#  416      FERRARI        488            Pista        282.0
#  417      FERRARI        488     Pista Spider        289.0
#  418      FERRARI        812              GTS        373.0
#  419      FERRARI        812        Superfast        366.0
#  420      FERRARI         F8           Spider        296.0
#  421      FERRARI         F8          Tributo        292.0
#  422      FERRARI       GTC4            Lusso        366.0
#  423      FERRARI       GTC4          Lusso T        294.0
#  424      FERRARI      Monza              SP1        366.0
#  425      FERRARI      Monza              SP2        366.0
#  426      FERRARI  Portofino        Portofino        267.0
#  427      FERRARI       Roma             Roma        255.0
#  428      FERRARI       SF90  Assetto Fiorano        160.0
#  429      FERRARI       SF90         Stradale        154.0,
#       Manufacturer     Model                 Description  Cleaned CO2
#  3005  Rolls Royce  Cullinan                    Cullinan        372.5
#  3006  Rolls Royce  Cullinan        Cullinan Black Badge        376.5
#  3007  Rolls Royce      Dawn                        Dawn        369.0
#  3008  Rolls Royce      Dawn    Dawn Black Badge Edition        364.0
#  3009  Rolls Royce     Ghost                       Ghost        353.0
#  3010  Rolls Royce     Ghost    Ghost Extended Wheelbase        353.0
#  3011  Rolls Royce   Phantom                     Phantom        353.5
#  3012  Rolls Royce   Phantom  Phantom Extended Wheelbase        353.5
#  3013  Rolls Royce    Wraith                      Wraith        360.0
#  3014  Rolls Royce    Wraith  Wraith Black Badge Edition        364.0]

# %%
# Put treatments into a list for for loop (and later for plot labels)
#treatments = [capomulin, ramicane, infubinol, ceftamin]


# Create empty list to fill with emissions data (for plotting)
outliers = []
quartile_sum = pd.DataFrame({})
# Calculate the IQR and quantitatively determine if there are any potential outliers. 


for brand in cars:
    #instantiate q0->5
    quartiles = brand["Cleaned CO2"].quantile([.25,.5,.75])
    
    lowerq = quartiles[0.25]
    median = quartiles[0.5]    
    upperq = quartiles[0.75]
    lowest = brand["Cleaned CO2"].min()
    highest = brand["Cleaned CO2"].max()
    
    iqr = upperq-lowerq
    
    #outlier check
    #HANG ON surely this can be done simpler with booleans
    x = brand.loc[brand["Cleaned CO2"] < (lowerq - iqr*1.5)]
    if len(x) > 0:
        outliers.append(x["Description"])
        
    x = brand.loc[brand["Cleaned CO2"] > (upperq + iqr*1.5)]
    if len(x) >0:
        outliers.append(x["Description"])
        
#investigate a better way to do this...
    cardict = {"brand": brand["Manufacturer"], 
                "Q0": round(lowest, 1), 
                "Q1": round(lowerq, 1), 
                "Q2": round(median, 1), 
                "Q3": round(upperq, 1), 
                "Q4": round(highest, 1)}   
    quartile_sum = quartile_sum.append(cardict, ignore_index=True)
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # Determine outliers using upper and lower bounds
print(f"there are {len(outliers)} outliers in the data: {outliers}")
    # add subset 
    
# # format nicely    
quartile_sum = quartile_sum.transpose()
# quartile_sum.columns = quartile_sum.iloc[0] 
# quartile_sum = quartile_sum[1:]
quartile_sum
# Out:
# there are 1 outliers in the data: [111    Bentayga Hybrid
# Name: Description, dtype: object]
#                                               0  \
# brand  0    0
# Name: Manufacturer, dtype: object
# Q0                                          0.0
# Q1                                          0.0
# Q2                                          0.0
# Q3                                          0.0
# Q4                                          0.0
#
#                                                        1  \
# brand  3269    TESLA
# 3270    TESLA
# 3271    TESLA
# 3272...
# Q0                                                   0.0
# Q1                                                   0.0
# Q2                                                   0.0
# Q3                                                   0.0
# Q4                                                   0.0
#
#                                                        2  \
# brand  3200    SMART
# 3201    SMART
# 3202    SMART
# 3203...
# Q0                                                   0.0
# Q1                                                   0.0
# Q2                                                   0.0
# Q3                                                   0.0
# Q4                                                   0.0
#
#                                                        3  \
# brand  111    BENTLEY MOTORS
# 112    BENTLEY MOTORS
# 11...
# Q0                                                  82.0
# Q1                                                 281.0
# Q2                                                 288.0
# Q3                                                 320.0
# Q4                                                 340.0
#
#                                                        4  \
# brand  416    FERRARI
# 417    FERRARI
# 418    FERRARI
# 4...
# Q0                                                 154.0
# Q1                                                 270.8
# Q2                                                 293.0
# Q3                                                 366.0
# Q4                                                 373.0
#
#                                                        5
# brand  3005    Rolls Royce
# 3006    Rolls Royce
# 3007  ...
# Q0                                                 353.0
# Q1                                                 353.5
# Q2                                                 362.0
# Q3                                                 367.8
# Q4                                                 376.5

# %%
# Generate a box plot for each car manufacturer, of the CO2 emissions of their various vehicles.

    
data = []

for car in cars:
    data.append(car["Cleaned CO2"])

fig, ax = plt.subplots()
ax.set_title('Comparing the emissions vehicles by the three cleanest and three most polluting car companies')
ax.boxplot(data, labels = emissions_superstars_pooperstars, sym="*", widths=(0.8))

plt.xlabel("Manufacturer")
plt.ylabel("WLTP CO2")


fig.set_figheight(8)
fig.set_figwidth(13)
plt.show()
