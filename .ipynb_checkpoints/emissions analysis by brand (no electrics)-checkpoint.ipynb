# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np
import random

# %%
euro = "data/Euro_6_CLEAN.csv"
euro_df = pd.read_csv(euro, encoding='ANSI', index_col="Unnamed: 0")
euro_df
# Out:
#      Manufacturer       Model                                 Description  \
# 0          ABARTH         595                             1.4 TJET 145bhp
# 1          ABARTH         595                             1.4 TJET 145bhp
# 2          ABARTH         595                            595 1.4 145 BHP
# 3          ABARTH         595                             595 1.4 145 BHP
# 4          ABARTH         595                 595 1.4 145 BHP Convertible
# ...           ...         ...                                         ...
# 6329        VOLVO  XC90, MY22  Recharge T8 Plug-in Hybrid Inscription Pro
# 6330        VOLVO  XC90, MY22         Recharge T8 Plug-in Hybrid R-Design
# 6331        VOLVO  XC90, MY22         Recharge T8 Plug-in Hybrid R-Design
# 6332        VOLVO  XC90, MY22     Recharge T8 Plug-in Hybrid R-Design Pro
# 6333        VOLVO  XC90, MY22     Recharge T8 Plug-in Hybrid R-Design Pro
#
#      Transmission Manual or Automatic  Engine Capacity             Fuel Type  \
# 0              M5              Manual           1368.0                Petrol
# 1              M5              Manual           1368.0                Petrol
# 2              M5              Manual           1368.0                Petrol
# 3              M5              Manual           1368.0                Petrol
# 4              M5              Manual           1368.0                Petrol
# ...           ...                 ...              ...                   ...
# 6329       8A-AWD           Automatic           1969.0  Electricity / Petrol
# 6330       8A-AWD           Automatic           1969.0  Electricity / Petrol
# 6331       8A-AWD           Automatic           1969.0  Electricity / Petrol
# 6332       8A-AWD           Automatic           1969.0  Electricity / Petrol
# 6333       8A-AWD           Automatic           1969.0  Electricity / Petrol
#
#                                   Powertrain  Engine Power (PS)  \
# 0           Internal Combustion Engine (ICE)              145.0
# 1           Internal Combustion Engine (ICE)              145.0
# 2           Internal Combustion Engine (ICE)              145.0
# 3           Internal Combustion Engine (ICE)              145.0
# 4           Internal Combustion Engine (ICE)              145.0
# ...                                      ...                ...
# 6329  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
# 6330  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
# 6331  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
# 6332  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
# 6333  Plug-in Hybrid Electric Vehicle (PHEV)              390.0
#
#       Engine Power (Kw)  ...  Emissions CO [mg/km]  THC Emissions [mg/km]  \
# 0                 107.0  ...                 829.0                   39.0
# 1                 107.0  ...                 829.0                   39.0
# 2                 107.0  ...                 760.0                   52.0
# 3                 107.0  ...                 760.0                   52.0
# 4                 107.0  ...                 760.0                   52.0
# ...                 ...  ...                   ...                    ...
# 6329              288.0  ...                 706.0                    6.0
# 6330              288.0  ...                 706.0                    6.0
# 6331              288.0  ...                 706.0                    6.0
# 6332              288.0  ...                 706.0                    6.0
# 6333              288.0  ...                 706.0                    6.0
#
#       Emissions NOx [mg/km]  THC + NOx Emissions [mg/km]  \
# 0                      20.0                         59.0
# 1                      20.0                         59.0
# 2                      27.0                         79.0
# 3                      27.0                         79.0
# 4                      27.0                         79.0
# ...                     ...                          ...
# 6329                    9.0                         14.0
# 6330                    9.0                         14.0
# 6331                    9.0                         14.0
# 6332                    9.0                         14.0
# 6333                    9.0                         14.0
#
#      Particulates [No.] [mg/km] RDE NOx Urban RDE NOx Combined  \
# 0                           NaN           NaN              NaN
# 1                           NaN           NaN              NaN
# 2                           NaN           NaN              NaN
# 3                           NaN           NaN              NaN
# 4                           NaN           NaN              NaN
# ...                         ...           ...              ...
# 6329                       0.22           NaN              NaN
# 6330                       0.22           NaN              NaN
# 6331                       0.22           NaN              NaN
# 6332                       0.22           NaN              NaN
# 6333                       0.22           NaN              NaN
#
#       Noise Level dB(A)  Date of change  Cleaned CO2
# 0                  74.0       09-Feb-22        161.0
# 1                  74.0       09-Feb-22        153.0
# 2                  73.5       05-Oct-20        169.0
# 3                  73.5       05-Oct-20        162.0
# 4                  73.5       02-Jul-21        169.0
# ...                 ...             ...          ...
# 6329               67.0       13-Aug-21         76.0
# 6330               67.0       13-Aug-21         57.0
# 6331               67.0       13-Aug-21         76.0
# 6332               67.0       13-Aug-21         57.0
# 6333               67.0       13-Aug-21         76.0
#
# [6334 rows x 45 columns]

# %%
euro_emissions = euro_df.drop(euro_df.loc[euro_df["Fuel Type"]  == "Electricity"].index)

euro_emissions = euro_emissions.groupby(['Manufacturer', 'Model', 'Description'], as_index=False).mean()
euro_emissions=euro_emissions.drop(labels=0)

# %%
manu_emissions = euro_emissions.groupby(['Manufacturer'], as_index=False).mean().sort_values(by='Cleaned CO2')
manu_emissions = manu_emissions[['Manufacturer', 'Cleaned CO2']]
manu_emissions
# Out:
#             Manufacturer  Cleaned CO2
# 36                SUZUKI   117.266667
# 10                    DS   122.400000
# 16               HYUNDAI   129.059783
# 37                TOYOTA   132.363636
# 30               PEUGEOT   134.950758
# 15                 HONDA   136.570792
# 31               RENAULT   137.325362
# 18                   KIA   138.298780
# 38                 VOLVO   138.375000
# 8                CITROEN   139.268750
# 25          MG MOTORS UK   140.038462
# 9                  DACIA   141.895115
# 12                  FIAT   143.787234
# 33                  SEAT   143.881081
# 29                NISSAN   143.886364
# 23                 MAZDA   148.549383
# 20                 LEXUS   152.516393
# 2                 ALPINE   157.071429
# 13                  FORD   163.150407
# 0                 ABARTH   166.022222
# 27  MORGAN MOTOR COMPANY   171.000000
# 34             SSANGYONG   175.093750
# 26            MITSUBISHI   175.428571
# 24         MERCEDES-BENZ   176.106944
# 7          CHRYSLER JEEP   179.058824
# 1             ALFA ROMEO   183.122222
# 5               CADILLAC   186.666667
# 35                SUBARU   188.600000
# 17                JAGUAR   203.575472
# 14               GENESIS   203.707317
# 21                 LOTUS   211.687500
# 19            LAND ROVER   231.665242
# 22              MASERATI   268.838710
# 28               McLaren   276.000000
# 6              CHEVROLET   277.000000
# 3   ASTON MARTIN LAGONDA   282.476190
# 4         BENTLEY MOTORS   289.705882
# 11               FERRARI   294.714286
# 32           Rolls Royce   361.900000

# %%
emissions_superstars_pooperstars = []
for n in range (0, 3):
    emissions_superstars_pooperstars.append(manu_emissions.iloc[n]['Manufacturer'])
    
for n in range (len(manu_emissions)-3, len(manu_emissions)):
    emissions_superstars_pooperstars.append(manu_emissions.iloc[n]['Manufacturer'])
    
print(emissions_superstars_pooperstars)
# Out:
# ['SUZUKI', 'DS', 'HYUNDAI', 'BENTLEY MOTORS', 'FERRARI', 'Rolls Royce']

# %%
cars = []
euro_emissions_crop = euro_emissions[['Manufacturer', 'Model', 'Description', 'Cleaned CO2']]

for manufacturer in emissions_superstars_pooperstars:
    carDF = euro_emissions_crop.loc[((euro_emissions_crop["Manufacturer"] == manufacturer ))]
    carDF.sort_values(by="Cleaned CO2", ascending=True)
    cars.append(carDF) 

cars
# Out:
# [     Manufacturer        Model                           Description  \
#  3132       SUZUKI       Across       ACROSS 2.5 PHEV SZ5 ALLGRIP CVT
#  3133       SUZUKI        Ignis                 IGNIS 1.2 HYBRID SZ-T
#  3134       SUZUKI        Ignis             IGNIS 1.2 HYBRID SZ-T CVT
#  3135       SUZUKI        Ignis                  IGNIS 1.2 HYBRID SZ3
#  3136       SUZUKI        Ignis                  IGNIS 1.2 HYBRID SZ5
#  3137       SUZUKI        Ignis              IGNIS 1.2 HYBRID SZ5 4x4
#  3138       SUZUKI        Ignis              IGNIS 1.2 HYBRID SZ5 CVT
#  3139       SUZUKI      S-cross               S-CROSS 1.4 HYBRID SZ-T
#  3140       SUZUKI      S-cross          S-CROSS 1.4 HYBRID SZ-T Auto
#  3141       SUZUKI      S-cross                S-CROSS 1.4 HYBRID SZ4
#  3142       SUZUKI      S-cross                S-CROSS 1.4 HYBRID SZ5
#  3143       SUZUKI      S-cross        S-CROSS 1.4 HYBRID SZ5 ALLGRIP
#  3144       SUZUKI      S-cross   S-CROSS 1.4 HYBRID SZ5 ALLGRIP Auto
#  3145       SUZUKI        Swace             SWACE 1.8 HYBRID SZ-T CVT
#  3146       SUZUKI        Swace              SWACE 1.8 HYBRID SZ5 CVT
#  3147       SUZUKI        Swift         SWIFT 1.2 DualJet HYBRID SZ-L
#  3148       SUZUKI        Swift         SWIFT 1.2 DualJet HYBRID SZ-T
#  3149       SUZUKI        Swift     SWIFT 1.2 DualJet HYBRID SZ-T CVT
#  3150       SUZUKI        Swift          SWIFT 1.2 DualJet HYBRID SZ5
#  3151       SUZUKI        Swift  SWIFT 1.2 DualJet HYBRID SZ5 ALLGRIP
#  3152       SUZUKI        Swift      SWIFT 1.2 DualJet HYBRID SZ5 CVT
#  3153       SUZUKI  Swift Sport          SWIFT 1.4 B/JET HYBRID SPORT
#  3154       SUZUKI       Vitara                VITARA 1.4 HYBRID SZ-T
#  3155       SUZUKI       Vitara        VITARA 1.4 HYBRID SZ-T ALLGRIP
#  3156       SUZUKI       Vitara           VITARA 1.4 HYBRID SZ-T Auto
#  3157       SUZUKI       Vitara                 VITARA 1.4 HYBRID SZ4
#  3158       SUZUKI       Vitara                 VITARA 1.4 HYBRID SZ5
#  3159       SUZUKI       Vitara         VITARA 1.4 HYBRID SZ5 ALLGRIP
#  3160       SUZUKI       Vitara    VITARA 1.4 HYBRID SZ5 ALLGRIP Auto
#  3161       SUZUKI       Vitara            VITARA 1.4 HYBRID SZ5 Auto
#
#        Cleaned CO2
#  3132         22.0
#  3133        112.0
#  3134        122.0
#  3135        110.0
#  3136        112.0
#  3137        121.0
#  3138        122.0
#  3139        122.0
#  3140        129.0
#  3141        122.0
#  3142        122.0
#  3143        133.0
#  3144        142.0
#  3145        103.0
#  3146        103.0
#  3147        106.0
#  3148        106.0
#  3149        115.0
#  3150        106.0
#  3151        121.0
#  3152        115.0
#  3153        125.0
#  3154        121.0
#  3155        132.0
#  3156        129.0
#  3157        121.0
#  3158        121.0
#  3159        132.0
#  3160        142.0
#  3161        129.0  ,
#      Manufacturer           Model             Description  Cleaned CO2
#  398           DS  DS 3 CROSSBACK      BlueHDi 100 Manual        121.0
#  399           DS  DS 3 CROSSBACK     PureTech 100 Manual        130.5
#  400           DS  DS 3 CROSSBACK  PureTech 130 Automatic        140.0
#  401           DS  DS 3 CROSSBACK  PureTech 155 Automatic        145.0
#  402           DS           DS 4   Blue HDi 130 Automatic        132.5
#  403           DS           DS 4    E-TENSE 225 Automatic         31.0
#  404           DS           DS 4   PureTech 130 Automatic        143.0
#  405           DS           DS 4   PureTech 180 Automatic        156.0
#  406           DS           DS 4   PureTech 225 Automatic        157.0
#  407           DS  DS 7 CROSSBACK   BlueHDi 130 Automatic        140.0
#  408           DS  DS 7 CROSSBACK             E-TENSE 225         35.0
#  409           DS  DS 7 CROSSBACK             E-TENSE 4x4         33.5
#  410           DS  DS 7 CROSSBACK  PureTech 130 Automatic        152.0
#  411           DS  DS 7 CROSSBACK  PureTech 180 Automatic        159.0
#  412           DS  DS 7 CROSSBACK  PureTech 225 Automatic        160.5,
#      Manufacturer           Model  \
#  686      HYUNDAI           Bayon
#  687      HYUNDAI           Bayon
#  688      HYUNDAI           Bayon
#  689      HYUNDAI           IONIQ
#  690      HYUNDAI           IONIQ
#  691      HYUNDAI            Kona
#  692      HYUNDAI            Kona
#  693      HYUNDAI            Kona
#  694      HYUNDAI            Kona
#  695      HYUNDAI            Kona
#  696      HYUNDAI            Kona
#  697      HYUNDAI            Kona
#  698      HYUNDAI        Santa Fe
#  699      HYUNDAI        Santa Fe
#  700      HYUNDAI        Santa Fe
#  701      HYUNDAI        Santa Fe
#  702      HYUNDAI        Santa Fe
#  703      HYUNDAI          Tucson
#  704      HYUNDAI          Tucson
#  705      HYUNDAI          Tucson
#  706      HYUNDAI          Tucson
#  707      HYUNDAI          Tucson
#  708      HYUNDAI          Tucson
#  709      HYUNDAI            i10
#  710      HYUNDAI            i10
#  711      HYUNDAI            i10
#  712      HYUNDAI            i10
#  713      HYUNDAI            i10
#  714      HYUNDAI            i10
#  715      HYUNDAI             i20
#  716      HYUNDAI             i20
#  717      HYUNDAI             i20
#  718      HYUNDAI             i20
#  719      HYUNDAI             i20
#  720      HYUNDAI    i30 Fastback
#  721      HYUNDAI  i30 Fastback N
#  722      HYUNDAI   i30 Hatchback
#  723      HYUNDAI   i30 Hatchback
#  724      HYUNDAI   i30 Hatchback
#  725      HYUNDAI   i30 Hatchback
#  726      HYUNDAI   i30 Hatchback
#  727      HYUNDAI           i30 N
#  728      HYUNDAI      i30 Tourer
#  729      HYUNDAI      i30 Tourer
#  730      HYUNDAI      i30 Tourer
#  731      HYUNDAI      i30 Tourer
#
#                                          Description  Cleaned CO2
#  686                                         Premium       120.50
#  687                                      SE Connect       119.50
#  688                                        Ultimate       121.00
#  689                                      Premium SE       105.00
#  690                            SE Connect & Premium       102.00
#  691                     1.0 T-GDi 48V MHEV, Premium       137.00
#  692                  1.0 T-GDi 48V MHEV, SE Connect       135.00
#  693           1.0 T-GDi 48V MHEV, Ultimate & N Line       138.00
#  694                    Hybrid Premium 21MY Facelift       114.00
#  695                   Hybrid Ultimate 21MY Facelift       115.00
#  696                                          Kona N       194.00
#  697                                      SE Connect       112.00
#  698                              Premium & Ultimate        37.00
#  699                              Premium Hybrid 2WD       145.00
#  700                              Premium Hybrid 4WD       159.00
#  701                             Ultimate Hybrid 2WD       152.00
#  702                             Ultimate Hybrid 4WD       168.00
#  703                                          N Line       145.00
#  704                                        N Line S       149.75
#  705                                         Premium       145.25
#  706                              Premium & Ultimate        31.00
#  707                                      SE Connect       139.00
#  708                                        Ultimate       154.75
#  709                                    1.0l Premium       123.00
#  710                                         1.0l SE       114.00
#  711                                 1.0l SE Connect       122.50
#  712                                    1.2l Premium       127.00
#  713                                 1.2l SE Connect       127.00
#  714                                    N Line T-GDi       123.00
#  715  1.0l T-GDi 48v Mild Hybrid, Premium & Ultimate       119.50
#  716          1.0l T-GDi 48v Mild Hybrid, SE Connect       116.00
#  717                                         Element       120.00
#  718                                               N       158.00
#  719                                          N Line       120.00
#  720                      1.5l T-GDi 48v Mild Hybrid       138.50
#  721                          Fastback N Performance       186.50
#  722             1.0l T-GDi 48v Mild Hybrid, Premium       121.50
#  723          1.0l T-GDi 48v Mild Hybrid, SE Connect       120.50
#  724              1.5l T-GDi 48v Mild Hybrid, N Line       140.00
#  725              1.6l CRDi 48v Mild Hybrid, Premium       124.50
#  726           1.6l CRDi 48v Mild Hybrid, SE Connect       123.50
#  727                                   N Performance       186.50
#  728             1.0l T-GDi 48v Mild Hybrid, Premium       121.00
#  729          1.0l T-GDi 48v Mild Hybrid, SE Connect       119.00
#  730              1.6l CRDi 48v Mild Hybrid, Premium       124.00
#  731           1.6l CRDi 48v Mild Hybrid, SE Connect       122.50  ,
#         Manufacturer                   Model  \
#  111  BENTLEY MOTORS           Bentayga MY21
#  112  BENTLEY MOTORS           Bentayga MY21
#  113  BENTLEY MOTORS     Continental GT MY21
#  114  BENTLEY MOTORS     Continental GT MY21
#  115  BENTLEY MOTORS     Continental GT MY22
#  116  BENTLEY MOTORS     Continental GT MY22
#  117  BENTLEY MOTORS  Continental GT V8 MY21
#  118  BENTLEY MOTORS  Continental GT V8 MY21
#  119  BENTLEY MOTORS  Continental GT V8 MY21
#  120  BENTLEY MOTORS  Continental GT V8 MY21
#  121  BENTLEY MOTORS  Continental GT V8 MY22
#  122  BENTLEY MOTORS  Continental GT V8 MY22
#  123  BENTLEY MOTORS        Flying Spur MY21
#  124  BENTLEY MOTORS        Flying Spur MY21
#  125  BENTLEY MOTORS        Flying Spur MY21
#  126  BENTLEY MOTORS        Flying Spur MY22
#  127  BENTLEY MOTORS        Flying Spur MY22
#
#                                      Description  Cleaned CO2
#  111                             Bentayga Hybrid         82.0
#  112                                 Bentayga V8        298.0
#  113                              Continental GT        308.0
#  114                  Continental GT Convertible        336.0
#  115                        Continental GT Speed        311.0
#  116            Continental GT Speed Convertible        320.0
#  117       Continental GT V8 Convertible Euro 6d        284.0
#  118  Continental GT V8 Convertible Euro 6d-TEMP        281.0
#  119                   Continental GT V8 Euro 6d        275.0
#  120              Continental GT V8 Euro 6d-TEMP        278.0
#  121                           Continental GT V8        275.0
#  122               Continental GT V8 Convertible        284.0
#  123                                          V8        288.0
#  124                                 W12 Euro 6d        340.0
#  125                            W12 Euro 6d-TEMP        337.0
#  126                                 Flying Spur        340.0
#  127                              Flying Spur V8        288.0  ,
#      Manufacturer      Model      Description  Cleaned CO2
#  413      FERRARI        488            Pista        282.0
#  414      FERRARI        488     Pista Spider        289.0
#  415      FERRARI        812              GTS        373.0
#  416      FERRARI        812        Superfast        366.0
#  417      FERRARI         F8           Spider        296.0
#  418      FERRARI         F8          Tributo        292.0
#  419      FERRARI       GTC4            Lusso        366.0
#  420      FERRARI       GTC4          Lusso T        294.0
#  421      FERRARI      Monza              SP1        366.0
#  422      FERRARI      Monza              SP2        366.0
#  423      FERRARI  Portofino        Portofino        267.0
#  424      FERRARI       Roma             Roma        255.0
#  425      FERRARI       SF90  Assetto Fiorano        160.0
#  426      FERRARI       SF90         Stradale        154.0,
#       Manufacturer     Model                 Description  Cleaned CO2
#  2906  Rolls Royce  Cullinan                    Cullinan        372.5
#  2907  Rolls Royce  Cullinan        Cullinan Black Badge        376.5
#  2908  Rolls Royce      Dawn                        Dawn        369.0
#  2909  Rolls Royce      Dawn    Dawn Black Badge Edition        364.0
#  2910  Rolls Royce     Ghost                       Ghost        353.0
#  2911  Rolls Royce     Ghost    Ghost Extended Wheelbase        353.0
#  2912  Rolls Royce   Phantom                     Phantom        353.5
#  2913  Rolls Royce   Phantom  Phantom Extended Wheelbase        353.5
#  2914  Rolls Royce    Wraith                      Wraith        360.0
#  2915  Rolls Royce    Wraith  Wraith Black Badge Edition        364.0]

# %%
# Put treatments into a list for for loop (and later for plot labels)
#treatments = [capomulin, ramicane, infubinol, ceftamin]


# Create empty list to fill with emissions data (for plotting)
outliers = []
quartile_sum = pd.DataFrame({})
# Calculate the IQR and quantitatively determine if there are any potential outliers. 


for brand in cars:
    #instantiate q0->5
    quartiles = brand["Cleaned CO2"].quantile([.25,.5,.75])
    
    lowerq = quartiles[0.25]
    median = quartiles[0.5]    
    upperq = quartiles[0.75]
    lowest = brand["Cleaned CO2"].min()
    highest = brand["Cleaned CO2"].max()
    
    iqr = upperq-lowerq
    
    #outlier check
    #HANG ON surely this can be done simpler with booleans
    x = brand.loc[brand["Cleaned CO2"] < (lowerq - iqr*1.5)]
    if len(x) > 0:
        outliers.append(x["Description"])
        
    x = brand.loc[brand["Cleaned CO2"] > (upperq + iqr*1.5)]
    if len(x) >0:
        outliers.append(x["Description"])
        
#investigate a better way to do this...
    cardict = {"brand": brand["Manufacturer"], 
                "Q0": round(lowest, 1), 
                "Q1": round(lowerq, 1), 
                "Q2": round(median, 1), 
                "Q3": round(upperq, 1), 
                "Q4": round(highest, 1)}   
    quartile_sum = quartile_sum.append(cardict, ignore_index=True)
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # Determine outliers using upper and lower bounds
print(f"there are {len(outliers)} outliers in the data: {outliers}")
    # add subset 
    
# # format nicely    
quartile_sum = quartile_sum.transpose()
# quartile_sum.columns = quartile_sum.iloc[0] 
# quartile_sum = quartile_sum[1:]
quartile_sum
# Out:
# there are 5 outliers in the data: [3132    ACROSS 2.5 PHEV SZ5 ALLGRIP CVT
# Name: Description, dtype: object, 403    E-TENSE 225 Automatic
# 408              E-TENSE 225
# 409              E-TENSE 4x4
# Name: Description, dtype: object, 698    Premium & Ultimate
# 706    Premium & Ultimate
# Name: Description, dtype: object, 696                    Kona N
# 721    Fastback N Performance
# 727             N Performance
# Name: Description, dtype: object, 111    Bentayga Hybrid
# Name: Description, dtype: object]
#                                                        0  \
# brand  3132    SUZUKI
# 3133    SUZUKI
# 3134    SUZUKI
# 3...
# Q0                                                  22.0
# Q1                                                 112.0
# Q2                                                 121.0
# Q3                                                 128.0
# Q4                                                 142.0
#
#                                                        1  \
# brand  398    DS
# 399    DS
# 400    DS
# 401    DS
# 402   ...
# Q0                                                  31.0
# Q1                                                 125.8
# Q2                                                 140.0
# Q3                                                 154.0
# Q4                                                 160.5
#
#                                                        2  \
# brand  686    HYUNDAI
# 687    HYUNDAI
# 688    HYUNDAI
# 6...
# Q0                                                  31.0
# Q1                                                 119.6
# Q2                                                 123.2
# Q3                                                 143.8
# Q4                                                 194.0
#
#                                                        3  \
# brand  111    BENTLEY MOTORS
# 112    BENTLEY MOTORS
# 11...
# Q0                                                  82.0
# Q1                                                 281.0
# Q2                                                 288.0
# Q3                                                 320.0
# Q4                                                 340.0
#
#                                                        4  \
# brand  413    FERRARI
# 414    FERRARI
# 415    FERRARI
# 4...
# Q0                                                 154.0
# Q1                                                 270.8
# Q2                                                 293.0
# Q3                                                 366.0
# Q4                                                 373.0
#
#                                                        5
# brand  2906    Rolls Royce
# 2907    Rolls Royce
# 2908  ...
# Q0                                                 353.0
# Q1                                                 353.5
# Q2                                                 362.0
# Q3                                                 367.8
# Q4                                                 376.5

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
data = []

for car in cars:
    data.append(car["Cleaned CO2"])
fig, ax = plt.subplots()
ax.set_title('Comparing the emissions vehicles by the three best and three worst car companies')
ax.boxplot(data, labels = emissions_superstars_pooperstars, sym="*", widths=(0.8))

plt.xlabel("Manufacturer")
plt.ylabel("Cleaned CO2")


fig.set_figheight(8)
fig.set_figwidth(13)
plt.show()
